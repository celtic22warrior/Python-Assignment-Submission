# %%
x=2
y=5
xy='Hey'
print(x+y,xy)
# Out:
# 7 Hey

# %%
print("""My name is Rajath Kumar M.P.

I love Python.""")
# Out:
# My name is Rajath Kumar M.P.
#
# I love Python.

# %%
string1 = 'World'
print('Hello', string1)

string2 = '!'
print('Hello', string1, string2)
# Out:
# Hello World
# Hello World !

# %%
print('Hello' + string1 + string2)
# Out:
# HelloWorld!

# %%
print("Jan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug")
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug

# %%
print("I want \\n to be printed.")
# Out:
# I want \n to be printed.

# %%
x = 10
print(type(x))
 
s = 'abc'
print(type(s))
 
value= True
print(type(value))

percent=90.00
type(percent)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# float
